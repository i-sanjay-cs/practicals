# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv('car_evaluation.csv')
df
# Out:
#      buying_price maintenance_cost number_of_doors number_of_persons lug_boot  \
# 0           vhigh            vhigh               2                 4      med
# 1           vhigh            vhigh               2                 2    small
# 2           vhigh            vhigh               2                 2      med
# 3           vhigh            vhigh               2                 2      med
# 4           vhigh            vhigh               2                 2      med
# ...           ...              ...             ...               ...      ...
# 1722          low              low           5more              more      med
# 1723          low              low           5more              more      med
# 1724          low              low           5more              more      big
# 1725          low              low           5more              more      big
# 1726          low              low           5more              more      big
#
#      safety decision
# ...

# %%
# Encode categorical variables
label_encoders = {}
categorical_columns = ['buying_price', 'maintenance_cost', 'lug_boot','decision']
for col in categorical_columns:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    label_encoders[col] = le

# %%
# Encode the 'safety' column (target variable)
le_safety = LabelEncoder()
df['safety'] = le_safety.fit_transform(df['safety'])
label_encoders['safety'] = le_safety

# %%
# Separate the target variable
X = df.drop('safety', axis=1)  # Features
y = df['safety']  # Target

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)

# %%
rf_classifier.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16324\1095801362.py in ?()
# ----> 1 rf_classifier.fit(X_train, y_train)
#
# ~\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1148                 skip_parameter_validation=(
#    1149                     prefer_skip_nested_validation or global_skip_validation
#    1150                 )
#    1151             ):
# -> 1152                 return fit_method(estimator, *args, **kwargs)
#
# ~\AppData\Roaming\Python\Python311\site-packages\sklearn\ensemble\_forest.py in ?(self, X, y, sample_weight)
#     344         """
#     345         # Validate or convert input data
#     346         if issparse(y):
#     347             raise ValueError("sparse multilabel-indicator for y is not supported.")
# --> 348         X, y = self._validate_data(
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.preprocessing import LabelEncoder

# Step 1: Load and preprocess the dataset
# Load the dataset into a DataFrame
df = pd.read_csv('car_evaluation.csv')

# Encode categorical variables
label_encoders = {}
categorical_columns = ['buying_price', 'maintenance_cost', 'lug_boot']
for col in categorical_columns:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    label_encoders[col] = le

# Encode the 'safety' column (target variable)
le_safety = LabelEncoder()
df['safety'] = le_safety.fit_transform(df['safety'])
label_encoders['safety'] = le_safety

# %%
# Separate the target variable
X = df.iloc[:, [0, 1]]  # Features (assuming 'buying_price', 'maintenance_cost', and 'lug_boot' are the first three columns)
y = df['safety']  # Target

# Step 2: Train-Test Split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Step 3: Random Forest Model
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)

# Step 4: Train the Model
rf_classifier.fit(X_train, y_train)

# Step 5: Model Evaluation
y_pred = rf_classifier.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

# %%
print(f"Accuracy: {accuracy}")
print("Confusion Matrix:\n", conf_matrix)
print("Classification Report:\n", class_report)
# Out:
# Accuracy: 0.2678227360308285
# Confusion Matrix:
#  [[49 85 50]
#  [61 59 45]
#  [68 71 31]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.28      0.27      0.27       184
#            1       0.27      0.36      0.31       165
#            2       0.25      0.18      0.21       170
#
#     accuracy                           0.27       519
#    macro avg       0.27      0.27      0.26       519
# weighted avg       0.27      0.27      0.26       519
