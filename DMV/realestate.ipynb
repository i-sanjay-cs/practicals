# %%
import pandas as pd

# %%
#step 1
df = pd.read_csv('Bengaluru_House_Data.csv')

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
# Clean column names
df.columns = df.columns.str.replace(' ', '_')  # Remove spaces and replace with underscores
df.columns = df.columns.str.upper()

# %%
df
# Out:
#                   AREA_TYPE   AVAILABILITY                  LOCATION  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             SIZE  SOCIETY TOTAL_SQFT  BATH  BALCONY   PRICE
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df.isnull().sum()
# Out:
# AREA_TYPE          0
# AVAILABILITY       0
# LOCATION           1
# SIZE              16
# SOCIETY         5502
# TOTAL_SQFT         0
# BATH              73
# BALCONY          609
# PRICE              0
# dtype: int64

# %%
df['BALCONY'].fillna(df['BALCONY'].mean(),inplace=True)

# %%
df.isnull().sum()
# Out:
# AREA_TYPE          0
# AVAILABILITY       0
# LOCATION           1
# SIZE              16
# SOCIETY         5502
# TOTAL_SQFT         0
# BATH              73
# BALCONY            0
# PRICE              0
# dtype: int64

# %%
df
# Out:
#                   AREA_TYPE   AVAILABILITY                  LOCATION  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             SIZE  SOCIETY TOTAL_SQFT  BATH   BALCONY   PRICE
# 0          2 BHK  Coomee        1056   2.0  1.000000   39.07
# ...

# %%
subset_data = df[(df['AVAILABILITY'] == 'Ready To Move')]

# %%
subset_data
# Out:
#                   AREA_TYPE   AVAILABILITY               LOCATION       SIZE  \
# 1                Plot  Area  Ready To Move       Chikka Tirupathi  4 Bedroom
# 2            Built-up  Area  Ready To Move            Uttarahalli      3 BHK
# 3      Super built-up  Area  Ready To Move     Lingadheeranahalli      3 BHK
# 4      Super built-up  Area  Ready To Move               Kothanur      2 BHK
# 5      Super built-up  Area  Ready To Move             Whitefield      2 BHK
# ...                     ...            ...                    ...        ...
# 13314  Super built-up  Area  Ready To Move      Green Glen Layout      3 BHK
# 13315        Built-up  Area  Ready To Move             Whitefield  5 Bedroom
# 13316  Super built-up  Area  Ready To Move          Richards Town      4 BHK
# 13317        Built-up  Area  Ready To Move  Raja Rajeshwari Nagar      2 BHK
# 13319  Super built-up  Area  Ready To Move           Doddathoguru      1 BHK
#
# ...

# %%
subset_data = df[(df['AVAILABILITY'] == 'Ready To Move') & (df['BALCONY'] >= 3)]

# %%
subset_data
# Out:
#                   AREA_TYPE   AVAILABILITY               LOCATION       SIZE  \
# 1                Plot  Area  Ready To Move       Chikka Tirupathi  4 Bedroom
# 2            Built-up  Area  Ready To Move            Uttarahalli      3 BHK
# 11               Plot  Area  Ready To Move             Whitefield  4 Bedroom
# 17     Super built-up  Area  Ready To Move  Raja Rajeshwari Nagar      3 BHK
# 33     Super built-up  Area  Ready To Move  Raja Rajeshwari Nagar      3 BHK
# ...                     ...            ...                    ...        ...
# 13301  Super built-up  Area  Ready To Move               Kothanur      3 BHK
# 13303            Plot  Area  Ready To Move         Vidyaranyapura  5 Bedroom
# 13305          Carpet  Area  Ready To Move               Hulimavu      1 BHK
# 13307        Built-up  Area  Ready To Move           Billekahalli      3 BHK
# 13314  Super built-up  Area  Ready To Move      Green Glen Layout      3 BHK
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
df['AREA_TYPE_CATEGORY'] = label_encoder.fit_transform(df['AREA_TYPE'])

# %%
df['AREA_TYPE_CATEGORY']
# Out:
# 0        3
# 1        2
# 2        0
# 3        3
# 4        3
#         ..
# 13315    0
# 13316    3
# 13317    0
# 13318    3
# 13319    3
# Name: AREA_TYPE_CATEGORY, Length: 13320, dtype: int32

# %%
#One-Hot Encoding:

df_encoded = pd.get_dummies(df, columns=['Category'], prefix=['Category'])

# %%
df
# Out:
#                   AREA_TYPE   AVAILABILITY                  LOCATION  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             SIZE  SOCIETY TOTAL_SQFT  BATH   BALCONY   PRICE  \
# 0          2 BHK  Coomee        1056   2.0  1.000000   39.07
# ...

# %%
grouped_data = df.groupby(['AVAILABILITY', 'AREA_TYPE'])

# %%
grouped_data

# %%
summary_stats = grouped_data['PRICE'].mean()

# %%
summary_stats
# Out:
# AVAILABILITY          AREA_TYPE
# 14-Jul                Built-up  Area           43.710000
# 14-Nov                Built-up  Area           43.710000
# 15-Aug                Built-up  Area           62.000000
# 15-Dec                Built-up  Area          130.000000
# 15-Jun                Built-up  Area           97.000000
#                                                  ...
# Immediate Possession  Plot  Area               98.921875
# Ready To Move         Built-up  Area          106.508347
#                       Carpet  Area             96.592891
#                       Plot  Area              211.890609
#                       Super built-up  Area     91.884520
# Name: PRICE, Length: 152, dtype: float64

# %%
df
# Out:
#                   AREA_TYPE   AVAILABILITY                  LOCATION  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             SIZE  SOCIETY TOTAL_SQFT  BATH   BALCONY   PRICE  \
# 0          2 BHK  Coomee        1056   2.0  1.000000   39.07
# ...

# %%
import seaborn as sns
sns.boxplot(df['PRICE'])
# Out:
# <Axes: >

# %%
# Drop rows where 'PRICE' is greater than 500
df.drop(df[df['PRICE'] > 3500].index, inplace=True)
